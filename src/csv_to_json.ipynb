# %%
# download trades_for_website.csv and turn the dataframe into a JSON for the frontend
import pandas as pd
df = pd.read_csv('trades_for_website.csv')
df.to_json('trades_for_website.json', orient='records', indent=2)
